# %% [markdown]
# Diabetes Prediction - Train datasets using classification model:

# %%
import pandas as pd

print("Reading data: ")
diabetes_dataset = pd.read_csv("/Users/maheshg/Dropbox/Sample Datasets Kaggle/diabetes.csv")
diabetes_dataset.head(10)
# Out:
# Reading data:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# 0   121.0  medium  118.0   59.0    NaN    NaN   29.0  38.0     720.0
# 1   218.0   large  112.0   68.0    NaN    NaN   46.0  48.0     360.0
# 2   256.0   large  190.0   92.0  185.0   92.0   49.0  57.0     180.0
# 3   119.0   large  110.0   50.0    NaN    NaN   33.0  38.0     480.0
# 4   183.0  medium  138.0   80.0    NaN    NaN   44.0  41.0     300.0

# %%
diabetes_dataset.dropna(how="all")
diabetes_dataset.dropna(axis=1, how = "all")
# Out:
#         id   chol  stab.glu   hdl  ratio      glyhb    location  age  gender  \
# 0     1000  203.0        82  56.0    3.6   4.310000  Buckingham   46  female
# 1     1001  165.0        97  24.0    6.9   4.440000  Buckingham   29  female
# 2     1002  228.0        92  37.0    6.2   4.640000  Buckingham   58  female
# 3     1003   78.0        93  12.0    6.5   4.630000  Buckingham   67    male
# 4     1005  249.0        90  28.0    8.9   7.720000  Buckingham   64    male
# ..     ...    ...       ...   ...    ...        ...         ...  ...     ...
# 398  41506  296.0       369  46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000      Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000      Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000      Louisa   41  female
# 402  41756  159.0        88  79.0    2.0        NaN      Louisa   68  female
#
# ...

# %%
print(diabetes_dataset.isnull().values.any())
# Out:
# True

# %%
print(diabetes_dataset.isnull().sum().sum())
# Out:
# 575

# %%
print(diabetes_dataset.isnull().sum())
# Out:
# id            0
# chol          1
# stab.glu      0
# hdl           1
# ratio         1
# glyhb        13
# location      0
# age           0
# gender        0
# height        5
# weight        1
# frame        12
# bp.1s         5
# bp.1d         5
# bp.2s       262
# bp.2d       262
# waist         2
# hip           2
# time.ppn      3
# dtype: int64

# %% [markdown]
# Splitting the data :

# %%
diabetes_dataset.dropna(subset=['chol','time.ppn','hip','waist','bp.2d','bp.2s','bp.1d','bp.1s','frame','weight','height','gender','age','location','glyhb','ratio','hdl','stab.glu','chol'])
# Out:
#         id   chol  stab.glu    hdl  ratio      glyhb    location  age  gender  \
# 2     1002  228.0        92   37.0    6.2   4.640000  Buckingham   58  female
# 6     1011  195.0        92   41.0    4.8   4.840000  Buckingham   30    male
# 8     1016  177.0        87   49.0    3.6   4.840000  Buckingham   45    male
# 10    1024  242.0        82   54.0    4.5   4.770000      Louisa   60  female
# 15    1036  213.0        83   47.0    4.5   3.410000      Louisa   33  female
# ..     ...    ...       ...    ...    ...        ...         ...  ...     ...
# 394  41254  169.0       104   58.0    2.9   4.820000      Louisa   25  female
# 395  41500  179.0        85   50.0    3.6   4.990000      Louisa   37    male
# 397  41503  301.0        90  118.0    2.6   4.280000      Louisa   89  female
# 398  41506  296.0       369   46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89   54.0    5.3   4.390000      Louisa   51  female
#
# ...

# %%
diabetes_dataset.fillna(0)
# Out:
#         id   chol  stab.glu   hdl  ratio      glyhb    location  age  gender  \
# 0     1000  203.0        82  56.0    3.6   4.310000  Buckingham   46  female
# 1     1001  165.0        97  24.0    6.9   4.440000  Buckingham   29  female
# 2     1002  228.0        92  37.0    6.2   4.640000  Buckingham   58  female
# 3     1003   78.0        93  12.0    6.5   4.630000  Buckingham   67    male
# 4     1005  249.0        90  28.0    8.9   7.720000  Buckingham   64    male
# ..     ...    ...       ...   ...    ...        ...         ...  ...     ...
# 398  41506  296.0       369  46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000      Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000      Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000      Louisa   41  female
# 402  41756  159.0        88  79.0    2.0   0.000000      Louisa   68  female
#
# ...

# %%
diabetes_dataset.fillna(method="ffill")
# Out:
# /var/folders/bt/k7t4mr2j6kq79jv3vbj756z80000gn/T/ipykernel_25343/2889170382.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   diabetes_dataset.fillna(method="ffill")
#         id   chol  stab.glu   hdl  ratio      glyhb    location  age  gender  \
# 0     1000  203.0        82  56.0    3.6   4.310000  Buckingham   46  female
# 1     1001  165.0        97  24.0    6.9   4.440000  Buckingham   29  female
# 2     1002  228.0        92  37.0    6.2   4.640000  Buckingham   58  female
# 3     1003   78.0        93  12.0    6.5   4.630000  Buckingham   67    male
# 4     1005  249.0        90  28.0    8.9   7.720000  Buckingham   64    male
# ..     ...    ...       ...   ...    ...        ...         ...  ...     ...
# 398  41506  296.0       369  46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000      Louisa   51  female
# ...

# %%
diabetes_dataset.describe
# Out:
# <bound method NDFrame.describe of         id   chol  stab.glu   hdl  ratio      glyhb    location  age  gender  \
# 0     1000  203.0        82  56.0    3.6   4.310000  Buckingham   46  female
# 1     1001  165.0        97  24.0    6.9   4.440000  Buckingham   29  female
# 2     1002  228.0        92  37.0    6.2   4.640000  Buckingham   58  female
# 3     1003   78.0        93  12.0    6.5   4.630000  Buckingham   67    male
# 4     1005  249.0        90  28.0    8.9   7.720000  Buckingham   64    male
# ..     ...    ...       ...   ...    ...        ...         ...  ...     ...
# 398  41506  296.0       369  46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000      Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000      Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000      Louisa   41  female
# 402  41756  159.0        88  79.0    2.0        NaN      Louisa   68  female
#
# ...

# %%
print("Any remaining NaN values : ", diabetes_dataset.isnull().values.any())
# Out:
# Any remaining NaN values :  True

# %%
import numpy as np
diabetes_dataset.replace([np.inf, -np.inf],np.nan, inplace=True)
diabetes_dataset.fillna(0)
# Out:
#         id   chol  stab.glu   hdl  ratio      glyhb    location  age  gender  \
# 0     1000  203.0        82  56.0    3.6   4.310000  Buckingham   46  female
# 1     1001  165.0        97  24.0    6.9   4.440000  Buckingham   29  female
# 2     1002  228.0        92  37.0    6.2   4.640000  Buckingham   58  female
# 3     1003   78.0        93  12.0    6.5   4.630000  Buckingham   67    male
# 4     1005  249.0        90  28.0    8.9   7.720000  Buckingham   64    male
# ..     ...    ...       ...   ...    ...        ...         ...  ...     ...
# 398  41506  296.0       369  46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000      Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000      Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000      Louisa   41  female
# 402  41756  159.0        88  79.0    2.0   0.000000      Louisa   68  female
#
# ...

# %%
diabetes_dataset.fillna(0)
# Out:
#         id   chol  stab.glu   hdl  ratio      glyhb    location  age  gender  \
# 0     1000  203.0        82  56.0    3.6   4.310000  Buckingham   46  female
# 1     1001  165.0        97  24.0    6.9   4.440000  Buckingham   29  female
# 2     1002  228.0        92  37.0    6.2   4.640000  Buckingham   58  female
# 3     1003   78.0        93  12.0    6.5   4.630000  Buckingham   67    male
# 4     1005  249.0        90  28.0    8.9   7.720000  Buckingham   64    male
# ..     ...    ...       ...   ...    ...        ...         ...  ...     ...
# 398  41506  296.0       369  46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000      Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000      Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000      Louisa   41  female
# 402  41756  159.0        88  79.0    2.0   0.000000      Louisa   68  female
#
# ...

# %%
print(diabetes_dataset.isnull().values.any())
# Out:
# True

# %%
diabetes_dataset.columns
# Out:
# Index(['id', 'chol', 'stab.glu', 'hdl', 'ratio', 'glyhb', 'location', 'age',
#        'gender', 'height', 'weight', 'frame', 'bp.1s', 'bp.1d', 'bp.2s',
#        'bp.2d', 'waist', 'hip', 'time.ppn'],
#       dtype='object')

# %%
diabetes_dataset.info
# Out:
# <bound method DataFrame.info of         id   chol  stab.glu   hdl  ratio      glyhb    location  age  gender  \
# 0     1000  203.0        82  56.0    3.6   4.310000  Buckingham   46  female
# 1     1001  165.0        97  24.0    6.9   4.440000  Buckingham   29  female
# 2     1002  228.0        92  37.0    6.2   4.640000  Buckingham   58  female
# 3     1003   78.0        93  12.0    6.5   4.630000  Buckingham   67    male
# 4     1005  249.0        90  28.0    8.9   7.720000  Buckingham   64    male
# ..     ...    ...       ...   ...    ...        ...         ...  ...     ...
# 398  41506  296.0       369  46.0    6.4  16.110001      Louisa   53    male
# 399  41507  284.0        89  54.0    5.3   4.390000      Louisa   51  female
# 400  41510  194.0       269  38.0    5.1  13.630000      Louisa   29  female
# 401  41752  199.0        76  52.0    3.8   4.490000      Louisa   41  female
# 402  41756  159.0        88  79.0    2.0        NaN      Louisa   68  female
#
# ...

# %%
diabetes_dataset.dropna(axis=1, how="all")
diabetes_dataset.dropna(axis=1, how="any")
# Out:
#         id  stab.glu    location  age  gender
# 0     1000        82  Buckingham   46  female
# 1     1001        97  Buckingham   29  female
# 2     1002        92  Buckingham   58  female
# 3     1003        93  Buckingham   67    male
# 4     1005        90  Buckingham   64    male
# ..     ...       ...         ...  ...     ...
# 398  41506       369      Louisa   53    male
# 399  41507        89      Louisa   51  female
# 400  41510       269      Louisa   29  female
# 401  41752        76      Louisa   41  female
# 402  41756        88      Louisa   68  female
#
# [403 rows x 5 columns]

# %%
print("Any remaining NaN values:",diabetes_dataset.isnull().values.any())
# Out:
# Any remaining NaN values: True

# %%
print("Splitting the data into features and labels:")

# X, y = diabetes_dataset[['age','stab.glu','height','weight','bp.1s', 'bp.1d', 'bp.2s',
#        'bp.2d']].values, diabetes_dataset['chol'].values

X, y = diabetes_dataset[['age','height','weight','bp.1s', 'bp.1d']].values, diabetes_dataset['chol'].values
# Out:
# Splitting the data into features and labels:

# %% [markdown]
# Splitting into Train and Test Set data:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=30, random_state=0)

# %% [markdown]
# Train Model using Logistic Regression (Classification Type)

# %%
from sklearn.linear_model import LogisticRegression
print("Training model:")
model = LogisticRegression(C=1/0.1, solver="liblinear").fit(X_train,y_train)
# Out:
# Training model:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 3
#       1 from sklearn.linear_model import LogisticRegression
#       2 print("Training model:")
# ----> 3 model = LogisticRegression(C=1/0.1, solver="liblinear").fit(X_train,y_train)
#
# File ~/Dropbox/git repos/PythonPractise/PythonPractise-1/study/lib/python3.9/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# ...
