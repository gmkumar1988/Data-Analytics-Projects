# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score,r2_score,mean_absolute_error,mean_squared_error

# %%
from sklearn.linear_model import LinearRegression

# %%
from pandas.core.common import random_state

# %%
ai_data = pd.read_csv('/Users/maheshg/Dropbox/Sample Datasets Kaggle/AI_Impact_on_Jobs_2030.csv')

# %%
ai_data.head()
# Out:
#              Job_Title  Average_Salary  Years_Experience Education_Level  \
# 0       Security Guard           45795                28        Master's
# 1   Research Scientist          133355                20             PhD
# 2  Construction Worker          146216                 2     High School
# 3    Software Engineer          136530                13             PhD
# 4    Financial Analyst           70397                22     High School
#
#    AI_Exposure_Index  Tech_Growth_Factor  Automation_Probability_2030  \
# 0               0.18                1.28                         0.85
# 1               0.62                1.11                         0.05
# 2               0.86                1.18                         0.81
# 3               0.39                0.68                         0.60
# 4               0.52                1.46                         0.64
#
#   Risk_Category  Skill_1  Skill_2  Skill_3  Skill_4  Skill_5  Skill_6  \
# ...

# %%
ai_data.describe()
# Out:
#        Average_Salary  Years_Experience  AI_Exposure_Index  \
# count     3000.000000       3000.000000        3000.000000
# mean     89372.279000         14.677667           0.501283
# std      34608.088767          8.739788           0.284004
# min      30030.000000          0.000000           0.000000
# 25%      58640.000000          7.000000           0.260000
# 50%      89318.000000         15.000000           0.500000
# 75%     119086.500000         22.000000           0.740000
# max     149798.000000         29.000000           1.000000
#
#        Tech_Growth_Factor  Automation_Probability_2030      Skill_1  \
# count         3000.000000                  3000.000000  3000.000000
# mean             0.995343                     0.501503     0.496973
# std              0.287669                     0.247881     0.287888
# min              0.500000                     0.050000     0.000000
# 25%              0.740000                     0.310000     0.240000
# ...

# %%
plt.title('AI Impact on Jobs 2030 - Job Counts by Sector')
sns.distplot(ai_data['Average_Salary'])
plt.show()
# Out:
# /var/folders/bt/k7t4mr2j6kq79jv3vbj756z80000gn/T/ipykernel_22440/689749906.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ai_data['Average_Salary'])

# %%
ai_data.columns
# Out:
# Index(['Job_Title', 'Average_Salary', 'Years_Experience', 'Education_Level',
#        'AI_Exposure_Index', 'Tech_Growth_Factor',
#        'Automation_Probability_2030', 'Risk_Category', 'Skill_1', 'Skill_2',
#        'Skill_3', 'Skill_4', 'Skill_5', 'Skill_6', 'Skill_7', 'Skill_8',
#        'Skill_9', 'Skill_10'],
#       dtype='object')

# %%
plt.scatter(ai_data['Years_Experience'],ai_data['Average_Salary'],
            color='lightcoral')
plt.xlabel('Years Experience')
plt.ylabel('Average Salary')
plt.title('AI Impact on Jobs 2030 - Salary vs Experience')
plt.show()

# %%
ai_data.columns
# Out:
# Index(['Job_Title', 'Average_Salary', 'Years_Experience', 'Education_Level',
#        'AI_Exposure_Index', 'Tech_Growth_Factor',
#        'Automation_Probability_2030', 'Risk_Category', 'Skill_1', 'Skill_2',
#        'Skill_3', 'Skill_4', 'Skill_5', 'Skill_6', 'Skill_7', 'Skill_8',
#        'Skill_9', 'Skill_10'],
#       dtype='object')

# %%
sns.barplot(x='Education_Level', y='Job_Title', data=ai_data, palette='viridis')
plt.title('AI Impact on Jobs 2030 - Job Counts by Sector')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/bt/k7t4mr2j6kq79jv3vbj756z80000gn/T/ipykernel_22440/1675639372.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Education_Level', y='Job_Title', data=ai_data, palette='viridis')

# %%
X = ai_data['Years_Experience'] # Independent Variable
y = ai_data['Average_Salary'] # Dependent Variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
### Regressor Model 
regressor = LinearRegression()
regressor.fit(np.array(X_train).reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
y_pred_test = regressor.predict(np.array(X_test).reshape(-1,1))
y_pred_train = regressor.predict(np.array(X_train).reshape(-1,1))

# %%
plt.scatter(X_train, y_train, color='blue')
plt.plot(X_train, y_pred_train, color='red')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years Experience')
plt.ylabel('Average Salary')
plt.show()
