# %% [markdown]
# Import the required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests

import seaborn as sns

# %%
API_KEY = "2IEW11B1BXR32H7M"

# %%
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=2IEW11B1BXR32H7M'

# %%
symbol = ['TD.TO', 'BNS.TO', 'RY.TO', 'CM.TO', 'NA.TO']

# %%
response = requests.get(url)
data = response.json()

# %%
response1 = response.json()
response1
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'IBM',
#   '3. Last Refreshed': '2025-06-20',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2025-06-20': {'1. open': '279.2800',
#    '2. high': '284.1200',
#    '3. low': '277.2000',
#    '4. close': '280.9700',
#    '5. volume': '7676962'},
#   '2025-06-18': {'1. open': '285.0000',
#    '2. high': '286.9100',
#    '3. low': '282.9400',
#    '4. close': '283.2100',
#    '5. volume': '3534110'},
#   '2025-06-17': {'1. open': '281.1500',
#    '2. high': '284.7899',
#    '3. low': '281.0001',
#    '4. close': '283.0500',
#    '5. volume': '3069556'},
#   '2025-06-16': {'1. open': '279.3050',
#    '2. high': '284.5000',
#    '3. low': '278.6657',
#    '4. close': '281.8300',
#    '5. volume': '3685321'},
#   '2025-06-13': {'1. open': '278.2050',
#    '2. high': '279.8400',
#    '3. low': '275.8300',
#    '4. close': '277.2200',
# ...

# %%
params = {
    'function': 'TIME_SERIES_DAILY_ADJUSTED',
    'symbol': symbol,
    'outputsize': 'compact',  # use 'full' for full history
    'apikey': API_KEY
}

# %%
timeseries = data.get('Time Series (Daily)', {})

# %%
df = pd.DataFrame.from_dict(timeseries, orient='index')

# %%
df = df.rename(columns=lambda x: x[3:].strip())  # Remove "1. ", "2. ", etc. from column names

# %%
df.index = pd.to_datetime(df.index)

# %%
df = df.sort_index()

# %%
df.columns = [col.split('. ')[1] if '. ' in col else col for col in df.columns]

# %%
df.head()
# Out:
#                 open      high       low     close    volume
# 2025-01-28  224.3200  225.7700  221.7700  225.6600   4485429
# 2025-01-29  225.6200  229.4700  223.7300  228.6300   7079804
# 2025-01-30  250.0000  261.8000  247.0100  258.2700  15381890
# 2025-01-31  256.0500  257.2350  251.8900  255.7000   7203519
# 2025-02-03  252.4000  262.0600  251.8400  260.7300   8408523
