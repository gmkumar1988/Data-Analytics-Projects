# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
silver_data = pd.read_csv('/Users/maheshg/Dropbox/Sample Datasets Kaggle/Silver_FuturePrice/silver_futures_price_data.csv')

# %%
# Display the first few rows of the dataset
print(silver_data.head())
# Out:
#    Close   High    Low   Open  Volume
# 0  4.930  4.950  4.895  4.950    2319
# 1  5.003  5.045  4.920  4.920    1612
# 2  5.004  5.035  4.985  5.035    1375
# 3  4.998  5.005  4.975  4.990     856
# 4  4.983  5.000  4.980  5.000     232

# %%
silver_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6348 entries, 0 to 6347
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   6348 non-null   float64
#  1   High    6348 non-null   float64
#  2   Low     6348 non-null   float64
#  3   Open    6348 non-null   float64
#  4   Volume  6348 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 248.1 KB

# %%
silver_data.isna().sum()
# Out:
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
silver_data.describe()
# Out:
#              Close         High          Low         Open         Volume
# count  6348.000000  6348.000000  6348.000000  6348.000000    6348.000000
# mean     17.864817    17.993645    17.735603    17.869737    1454.584436
# std       9.422887     9.526653     9.314798     9.422253    8442.851187
# min       4.026000     4.026000     4.026000     4.026000       0.000000
# 25%      12.122250    12.165000    12.038750    12.129500       5.000000
# 50%      16.979000    17.049999    16.893499    16.967500      36.000000
# 75%      23.459250    23.602000    23.328499    23.467250     142.000000
# max      63.929001    63.929001    61.875000    63.070000  170297.000000

# %%
silver_data.Volume.value_counts()
# Out:
# Volume
# 0        739
# 2        267
# 1        215
# 3        157
# 4        142
#         ...
# 83200      1
# 37642      1
# 4514       1
# 1737       1
# 335        1
# Name: count, Length: 1011, dtype: int64

# %%
silver_data.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
X = silver_data.drop('Open', axis=1)
y = silver_data['Open']

# %%
X.columns
# Out:
# Index(['Close', 'High', 'Low', 'Volume'], dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled[:3]
# Out:
# array([[-1.37281023, -1.36928184, -1.37862523,  0.10239238],
#        [-1.36506253, -1.359309  , -1.37594111,  0.0186463 ],
#        [-1.36495635, -1.36035879, -1.36896241, -0.00942699]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (5078, 4)

# %%
y_train.shape
# Out:
# (5078,)

# %%
X_test.shape
# Out:
# (1270, 4)

# %%
y_test.shape
# Out:
# (1270,)

# %%
from sklearn.tree import DecisionTreeRegressor
dt_regressor = DecisionTreeRegressor(random_state=42)
dt_regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y_predict = dt_regressor.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(y_test, y_predict)
mse = mean_squared_error(y_test, y_predict)
r2 = r2_score(y_test, y_predict)

# %%
mean_absolute_error(y_test, y_predict)
# Out:
# 0.11038426301610747

# %%
y_predicted_train = dt_regressor.predict(X_train)
mae_train = mean_absolute_error(y_train, y_predicted_train)
mae_train
# Out:
# 0.0

# %%
y_predicted_train
# Out:
# array([ 8.81999969,  4.6420002 , 15.84500027, ..., 25.84000015,
#        24.55500031,  6.579     ])

# %%
y_train
# Out:
# 1328     8.820000
# 57       4.642000
# 3593    15.845000
# 3319    19.930000
# 6305    51.259998
#           ...
# 3772    14.510000
# 5191    27.285000
# 5226    25.840000
# 5390    24.555000
# 860      6.579000
# Name: Open, Length: 5078, dtype: float64

# %% [markdown]
#         Based on the comparison of Y_train and Y_predicted_Train noticed it is exactly matching but foreseing this issue as Over fitting

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'max_depth': [3, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
rg1 = DecisionTreeRegressor()
rg1 = GridSearchCV(rg1,param_grid)

# %%
rg1.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [3, 5, 10], 'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]})

# %%
rg1.best_params_
# Out:
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2}

# %%
y_predict = rg1.predict(X_test)
mean_absolute_error(y_test, y_predict)
# Out:
# 0.11820789700440988

# %%
y_predicted_train = rg1.predict(X_train)
mean_absolute_error(y_train, y_predicted_train)
# Out:
# 0.055056556970567896
